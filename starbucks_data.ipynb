# %%
# Source file: https://www.kaggle.com/starbucks/store-locations

# %%
# Import dependencies:

import pandas as pd
from sqlalchemy import create_engine

# %%
# Read in csv:
raw_df = pd.read_csv('Resources/starbucks.csv')

# Take a look:
raw_df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
raw_df.dtypes
# Out:
# Brand              object
# Store Number       object
# Store Name         object
# Ownership Type     object
# Street Address     object
# City               object
# State/Province     object
# Country            object
# Postcode           object
# Phone Number       object
# Timezone           object
# Longitude         float64
# Latitude          float64
# dtype: object

# %%
# Strip out countries other than US:

us_df = raw_df.loc[raw_df['Country'] == 'US']
us_df.head()
# Out:
#            Brand  Store Number                 Store Name Ownership Type  \
# 11964  Starbucks   3513-125945    Safeway-Anchorage #1809       Licensed
# 11965  Starbucks   74352-84449    Safeway-Anchorage #2628       Licensed
# 11966  Starbucks  12449-152385  Safeway - Anchorage #1813       Licensed
# 11967  Starbucks  24936-233524   100th & C St - Anchorage  Company Owned
# 11968  Starbucks    8973-85630       Old Seward & Diamond  Company Owned
#
#                                           Street Address       City  \
# 11964                               5600 Debarr Rd Ste 9  Anchorage
# 11965                                     1725 Abbott Rd  Anchorage
# 11966                                    1501 Huffman Rd  Anchorage
# 11967  320 W. 100th Ave, 100, Southgate Shopping Ctr ...  Anchorage
# 11968                                 1005 E Dimond Blvd  Anchorage
#
#       State/Province Country   Postcode    Phone Number  \
# 11964             AK      US  995042300    907-339-0900
# 11965             AK      US  995073444    907-339-2800
# 11966             AK      US  995153596    907-339-1300
# 11967             AK      US      99515  (907) 227-9631
# 11968             AK      US  995152050    907-344-4160
#
#                           Timezone  Longitude  Latitude
# 11964  GMT-09:00 America/Anchorage    -149.78     61.21
# 11965  GMT-09:00 America/Anchorage    -149.84     61.14
# 11966  GMT-09:00 America/Anchorage    -149.85     61.11
# 11967  GMT-09:00 America/Anchorage    -149.89     61.13
# 11968  GMT-09:00 America/Anchorage    -149.86     61.14

# %%
# Create new dataframe with selected columns:
new_us_df = us_df[['Store Number', 'Street Address', 'City', 'State/Province', 'Country', 'Postcode', 'Longitude', 'Latitude']].copy()
new_us_df.head()
# Out:
#        Store Number                                     Street Address  \
# 11964   3513-125945                               5600 Debarr Rd Ste 9
# 11965   74352-84449                                     1725 Abbott Rd
# 11966  12449-152385                                    1501 Huffman Rd
# 11967  24936-233524  320 W. 100th Ave, 100, Southgate Shopping Ctr ...
# 11968    8973-85630                                 1005 E Dimond Blvd
#
#             City State/Province Country   Postcode  Longitude  Latitude
# 11964  Anchorage             AK      US  995042300    -149.78     61.21
# 11965  Anchorage             AK      US  995073444    -149.84     61.14
# 11966  Anchorage             AK      US  995153596    -149.85     61.11
# 11967  Anchorage             AK      US      99515    -149.89     61.13
# 11968  Anchorage             AK      US  995152050    -149.86     61.14

# %%
# Rename columns to make them SQL friendly:

new_us_df = new_us_df.rename(columns = {'Store Number': 'store_number',
                                        'Street Address': 'address',
                                        'City': 'city',
                                        'State/Province': 'state',
                                        'Country': 'country',
                                        'Postcode': 'zipcode',
                                        'Longitude': 'longitude',
                                        'Latitude': 'latitude'
                                       })

new_us_df.head()
# Out:
#        store_number                                            address  \
# 11964   3513-125945                               5600 Debarr Rd Ste 9
# 11965   74352-84449                                     1725 Abbott Rd
# 11966  12449-152385                                    1501 Huffman Rd
# 11967  24936-233524  320 W. 100th Ave, 100, Southgate Shopping Ctr ...
# 11968    8973-85630                                 1005 E Dimond Blvd
#
#             city state country    zipcode  longitude  latitude
# 11964  Anchorage    AK      US  995042300    -149.78     61.21
# 11965  Anchorage    AK      US  995073444    -149.84     61.14
# 11966  Anchorage    AK      US  995153596    -149.85     61.11
# 11967  Anchorage    AK      US      99515    -149.89     61.13
# 11968  Anchorage    AK      US  995152050    -149.86     61.14

# %%
# Dropping NA values for zip wasn't needed, since there were 13608 rows before and after.

#len(new_us_df)
#13608
#new_us_df['zipcode'] = new_us_df['zipcode'].dropna()
#len(new_us_df)
#13608

# %%
# Some zipcodes have the extra 4 digits on the right side, for 9 total.
# Remove four extra digits from string – Convert Zip+4 to Zip code:
# (source = https://stackoverflow.com/questions/44776115/remove-four-last-digits-from-string-convert-zip4-to-zip-code/44776170)
#  Ex.: df['collection_status'] = df['zip_code'].str[:5]

new_us_df['zipcode'] = new_us_df['zipcode'].str[:5]
new_us_df
# Out:
#        store_number                                            address  \
# 11964   3513-125945                               5600 Debarr Rd Ste 9
# 11965   74352-84449                                     1725 Abbott Rd
# 11966  12449-152385                                    1501 Huffman Rd
# 11967  24936-233524  320 W. 100th Ave, 100, Southgate Shopping Ctr ...
# 11968    8973-85630                                 1005 E Dimond Blvd
# ...             ...                                                ...
# 25567   74385-87621                                       554 N 3rd St
# 25568   73320-24375                                      3112 E. Grand
# 25569  22425-219024                                     3021 Grand Ave
# 25570  10849-103163                                   118 Westland Way
# 25571  10769-102454                                   2208 Coffeen Ave
#
#                city state country zipcode  longitude  latitude
# 11964     Anchorage    AK      US   99504    -149.78     61.21
# 11965     Anchorage    AK      US   99507    -149.84     61.14
# 11966     Anchorage    AK      US   99515    -149.85     61.11
# 11967     Anchorage    AK      US   99515    -149.89     61.13
# 11968     Anchorage    AK      US   99515    -149.86     61.14
# ...             ...   ...     ...     ...        ...       ...
# 25567       Laramie    WY      US   82072    -105.59     41.32
# 25568       Laramie    WY      US   82070    -105.56     41.31
# 25569       Laramie    WY      US   82070    -105.56     41.31
# 25570  Rock Springs    WY      US   82901    -109.25     41.58
# 25571     Sheridian    WY      US   82801    -106.94     44.77
#
# [13608 rows x 8 columns]

# %%
# Some zipcodes were only 4 digits, because the leading 0 got dropped somewhere.
# Show the zip for a store that didn't have a leading zero:

new_us_df.loc[new_us_df['store_number'] == '22967-176905']
# Out:
#        store_number             address           city state country zipcode  \
# 16055  22967-176905  200 Bloomfield Ave  West Hartford    CT      US    6117
#
#        longitude  latitude
# 16055     -72.72     41.79

# %%
# Add a leading zero to zip codes that were missing it and were only 4 digits:
# (source: https://www.datasciencemadesimple.com/add-leading-preceding-zeros-python/)

new_us_df['zipcode']=new_us_df['zipcode'].apply(lambda x: '{0:0>5}'.format(x))

# %%
# Show that a zipcode which previously had 4 digits now has 5, with a leading 0:

new_us_df.loc[new_us_df['store_number'] == '22967-176905']
# Out:
#        store_number             address           city state country zipcode  \
# 16055  22967-176905  200 Bloomfield Ave  West Hartford    CT      US   06117
#
#        longitude  latitude
# 16055     -72.72     41.79

# %%
new_us_df
# Out:
#        store_number                                            address  \
# 11964   3513-125945                               5600 Debarr Rd Ste 9
# 11965   74352-84449                                     1725 Abbott Rd
# 11966  12449-152385                                    1501 Huffman Rd
# 11967  24936-233524  320 W. 100th Ave, 100, Southgate Shopping Ctr ...
# 11968    8973-85630                                 1005 E Dimond Blvd
# ...             ...                                                ...
# 25567   74385-87621                                       554 N 3rd St
# 25568   73320-24375                                      3112 E. Grand
# 25569  22425-219024                                     3021 Grand Ave
# 25570  10849-103163                                   118 Westland Way
# 25571  10769-102454                                   2208 Coffeen Ave
#
#                city state country zipcode  longitude  latitude
# 11964     Anchorage    AK      US   99504    -149.78     61.21
# 11965     Anchorage    AK      US   99507    -149.84     61.14
# 11966     Anchorage    AK      US   99515    -149.85     61.11
# 11967     Anchorage    AK      US   99515    -149.89     61.13
# 11968     Anchorage    AK      US   99515    -149.86     61.14
# ...             ...   ...     ...     ...        ...       ...
# 25567       Laramie    WY      US   82072    -105.59     41.32
# 25568       Laramie    WY      US   82070    -105.56     41.31
# 25569       Laramie    WY      US   82070    -105.56     41.31
# 25570  Rock Springs    WY      US   82901    -109.25     41.58
# 25571     Sheridian    WY      US   82801    -106.94     44.77
#
# [13608 rows x 8 columns]

# %%
new_us_df.dtypes
# Out:
# store_number     object
# address          object
# city             object
# state            object
# country          object
# zipcode          object
# longitude       float64
# latitude        float64
# dtype: object

# %%
# Connect to local database:

rds_connection_string = "postgres:postgres@localhost:5432/starbucks_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Check for tables:
engine.table_names()
# Out:
# ['income_data', 'starbucks_data']

# %%
# Use pandas to load csv converted DataFrame into database
# (using "locations" as the name of the table for the Starbucks locations):

new_us_df.to_sql(name='starbucks_data', con=engine, if_exists='append', index=False)

# %%
# Confirm data has been added by querying the starbucks_data table:

pd.read_sql_query('select * from starbucks_data', con=engine).head()
# Out:
#    store_number                                            address       city  \
# 0   3513-125945                               5600 Debarr Rd Ste 9  Anchorage
# 1   74352-84449                                     1725 Abbott Rd  Anchorage
# 2  12449-152385                                    1501 Huffman Rd  Anchorage
# 3  24936-233524  320 W. 100th Ave, 100, Southgate Shopping Ctr ...  Anchorage
# 4    8973-85630                                 1005 E Dimond Blvd  Anchorage
#
#   state country zipcode  longitude  latitude
# 0    AK      US   99504    -149.78     61.21
# 1    AK      US   99507    -149.84     61.14
# 2    AK      US   99515    -149.85     61.11
# 3    AK      US   99515    -149.89     61.13
# 4    AK      US   99515    -149.86     61.14
